# %%
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

import os
from math import * 
os.getcwd()
print("The current directory is: ")
print(os.getcwd())
path_parent = os.path.dirname(os.getcwd())
if path_parent.endswith("Abaqus-Macromechanics-Project"):
    os.chdir(path_parent) 
    print("Moving up to the parent directory")
    print(os.getcwd())
# Out:
# The current directory is:
# c:\Users\springnuance\Desktop\Abaqus-Macromechanics-Project\notebooks
# Moving up to the parent directory
# c:\Users\springnuance\Desktop\Abaqus-Macromechanics-Project

# %%
FD_Curves_smooth_part1 = np.load("notebooks/NDBR20/025/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()
FD_Curves_smooth_part2 = np.load("notebooks/NDBR20/2550/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()
FD_Curves_smooth_part3 = np.load("notebooks/NDBR20/5075/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()
FD_Curves_smooth_part4 = np.load("notebooks/NDBR20/75100/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()
FD_Curves_smooth_part5 = np.load("notebooks/NDBR20/100125/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()
FD_Curves_smooth_part6 = np.load("notebooks/NDBR20/125150/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()
FD_Curves_smooth_part7 = np.load("notebooks/NDBR20/150175/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()
FD_Curves_smooth_part8 = np.load("notebooks/NDBR20/175200/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()

FD_Curves_unsmooth_part1 = np.load("notebooks/NDBR20/025/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()
FD_Curves_unsmooth_part2 = np.load("notebooks/NDBR20/2550/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()
FD_Curves_unsmooth_part3 = np.load("notebooks/NDBR20/5075/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()
FD_Curves_unsmooth_part4 = np.load("notebooks/NDBR20/75100/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()
FD_Curves_unsmooth_part5 = np.load("notebooks/NDBR20/100125/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()
FD_Curves_unsmooth_part6 = np.load("notebooks/NDBR20/125150/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()
FD_Curves_unsmooth_part7 = np.load("notebooks/NDBR20/150175/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()
FD_Curves_unsmooth_part8 = np.load("notebooks/NDBR20/175200/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()

flowCurves_part1 = np.load("notebooks/NDBR20/025/common/flowCurves.npy", allow_pickle=True).tolist()
flowCurves_part2 = np.load("notebooks/NDBR20/2550/common/flowCurves.npy", allow_pickle=True).tolist()
flowCurves_part3 = np.load("notebooks/NDBR20/5075/common/flowCurves.npy", allow_pickle=True).tolist()
flowCurves_part4 = np.load("notebooks/NDBR20/75100/common/flowCurves.npy", allow_pickle=True).tolist()
flowCurves_part5 = np.load("notebooks/NDBR20/100125/common/flowCurves.npy", allow_pickle=True).tolist()
flowCurves_part6 = np.load("notebooks/NDBR20/125150/common/flowCurves.npy", allow_pickle=True).tolist()
flowCurves_part7 = np.load("notebooks/NDBR20/150175/common/flowCurves.npy", allow_pickle=True).tolist()
flowCurves_part8 = np.load("notebooks/NDBR20/175200/common/flowCurves.npy", allow_pickle=True).tolist()

# %%
FD_Curves_smooth = {}
FD_Curves_unsmooth = {}
flowCurves = {}

FD_Curves_smooth.update(FD_Curves_smooth_part1)
FD_Curves_smooth.update(FD_Curves_smooth_part2)
FD_Curves_smooth.update(FD_Curves_smooth_part3)
FD_Curves_smooth.update(FD_Curves_smooth_part4)
FD_Curves_smooth.update(FD_Curves_smooth_part5)
FD_Curves_smooth.update(FD_Curves_smooth_part6)
FD_Curves_smooth.update(FD_Curves_smooth_part7)
FD_Curves_smooth.update(FD_Curves_smooth_part8)

FD_Curves_unsmooth.update(FD_Curves_unsmooth_part1)
FD_Curves_unsmooth.update(FD_Curves_unsmooth_part2)
FD_Curves_unsmooth.update(FD_Curves_unsmooth_part3)
FD_Curves_unsmooth.update(FD_Curves_unsmooth_part4)
FD_Curves_unsmooth.update(FD_Curves_unsmooth_part5)
FD_Curves_unsmooth.update(FD_Curves_unsmooth_part6)
FD_Curves_unsmooth.update(FD_Curves_unsmooth_part7)
FD_Curves_unsmooth.update(FD_Curves_unsmooth_part8)

flowCurves.update(flowCurves_part1)
flowCurves.update(flowCurves_part2)
flowCurves.update(flowCurves_part3)
flowCurves.update(flowCurves_part4)
flowCurves.update(flowCurves_part5)
flowCurves.update(flowCurves_part6)
flowCurves.update(flowCurves_part7)
flowCurves.update(flowCurves_part8)

np.save("MOO_results/DP1000_25C_SwiftVoce_curve1/NDBR20/initial/common/FD_Curves_smooth.npy", FD_Curves_smooth)
np.save("MOO_results/DP1000_25C_SwiftVoce_curve1/NDBR20/initial/common/FD_Curves_unsmooth.npy", FD_Curves_unsmooth)
np.save("MOO_results/DP1000_25C_SwiftVoce_curve1/NDBR20/initial/common/flowCurves.npy", flowCurves)

print(len(FD_Curves_smooth))
# Out:
# 200

# %%
import shutil
import os
import glob

import os
import shutil

def copy_recursive(src, dst):
    # If the source is a directory, create a new directory in the destination and copy its contents
    if os.path.isdir(src):
        if not os.path.exists(dst):
            os.makedirs(dst)
        for item in os.listdir(src):
            s = os.path.join(src, item)
            d = os.path.join(dst, item)
            copy_recursive(s, d)
    # If the source is a file, just copy it
    else:
        shutil.copy2(src, dst)

# %%
# Copying all files from the initial folder to the common folder

path1 = "notebooks/NDBR20/025/data"
path2 = "notebooks/NDBR20/2550/data"
path3 = "notebooks/NDBR20/5075/data"
path4 = "notebooks/NDBR20/75100/data"
path5 = "notebooks/NDBR20/100125/data"
path6 = "notebooks/NDBR20/125150/data"
path7 = "notebooks/NDBR20/150175/data"
path8 = "notebooks/NDBR20/175200/data"

dest = "MOO_results/DP1000_25C_SwiftVoce_curve1/NDBR20/initial/data"

copy_recursive(path2, dest)
# renaming all subfolders 1-25 as 26-50
for i in range(1,26):
    os.rename(os.path.join(dest, str(i)), os.path.join(dest, str(i+25)))

copy_recursive(path3, dest)
# renaming all subfolders 1-25 as 51-75
for i in range(1,26):
    os.rename(os.path.join(dest, str(i)), os.path.join(dest, str(i+50)))

copy_recursive(path4, dest)
# renaming all subfolders 1-25 as 76-100
for i in range(1,26):
    os.rename(os.path.join(dest, str(i)), os.path.join(dest, str(i+75)))

copy_recursive(path5, dest)
# renaming all subfolders 1-25 as 101-125
for i in range(1,26):
    os.rename(os.path.join(dest, str(i)), os.path.join(dest, str(i+100)))
copy_recursive(path6, dest)
# renaming all subfolders 1-25 as 126-150
for i in range(1,26):
    os.rename(os.path.join(dest, str(i)), os.path.join(dest, str(i+125)))

copy_recursive(path7, dest)
# renaming all subfolders 1-25 as 151-175
for i in range(1,26):
    os.rename(os.path.join(dest, str(i)), os.path.join(dest, str(i+150)))

copy_recursive(path8, dest)
# renaming all subfolders 1-25 as 176-200
for i in range(1,26):
    os.rename(os.path.join(dest, str(i)), os.path.join(dest, str(i+175)))

copy_recursive(path1, dest)

# %%
FD_Curves_smooth_part1 = np.load("notebooks/SH/025/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()
FD_Curves_smooth_part2 = np.load("notebooks/SH/2550/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()
FD_Curves_smooth_part3 = np.load("notebooks/SH/5075/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()
FD_Curves_smooth_part4 = np.load("notebooks/SH/75100/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()
FD_Curves_smooth_part5 = np.load("notebooks/SH/100125/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()
FD_Curves_smooth_part6 = np.load("notebooks/SH/125150/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()
FD_Curves_smooth_part7 = np.load("notebooks/SH/150175/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()
FD_Curves_smooth_part8 = np.load("notebooks/SH/175200/common/FD_Curves_smooth.npy", allow_pickle=True).tolist()

FD_Curves_unsmooth_part1 = np.load("notebooks/SH/025/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()
FD_Curves_unsmooth_part2 = np.load("notebooks/SH/2550/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()
FD_Curves_unsmooth_part3 = np.load("notebooks/SH/5075/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()
FD_Curves_unsmooth_part4 = np.load("notebooks/SH/75100/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()
FD_Curves_unsmooth_part5 = np.load("notebooks/SH/100125/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()
FD_Curves_unsmooth_part6 = np.load("notebooks/SH/125150/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()
FD_Curves_unsmooth_part7 = np.load("notebooks/SH/150175/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()
FD_Curves_unsmooth_part8 = np.load("notebooks/SH/175200/common/FD_Curves_unsmooth.npy", allow_pickle=True).tolist()

flowCurves_part1 = np.load("notebooks/SH/025/common/flowCurves.npy", allow_pickle=True).tolist()
flowCurves_part2 = np.load("notebooks/SH/2550/common/flowCurves.npy", allow_pickle=True).tolist()
flowCurves_part3 = np.load("notebooks/SH/5075/common/flowCurves.npy", allow_pickle=True).tolist()
flowCurves_part4 = np.load("notebooks/SH/75100/common/flowCurves.npy", allow_pickle=True).tolist()
flowCurves_part5 = np.load("notebooks/SH/100125/common/flowCurves.npy", allow_pickle=True).tolist()
flowCurves_part6 = np.load("notebooks/SH/125150/common/flowCurves.npy", allow_pickle=True).tolist()
flowCurves_part7 = np.load("notebooks/SH/150175/common/flowCurves.npy", allow_pickle=True).tolist()
flowCurves_part8 = np.load("notebooks/SH/175200/common/flowCurves.npy", allow_pickle=True).tolist()

FD_Curves_smooth = {}
FD_Curves_unsmooth = {}
flowCurves = {}

FD_Curves_smooth.update(FD_Curves_smooth_part1)
FD_Curves_smooth.update(FD_Curves_smooth_part2)
FD_Curves_smooth.update(FD_Curves_smooth_part3)
FD_Curves_smooth.update(FD_Curves_smooth_part4)
FD_Curves_smooth.update(FD_Curves_smooth_part5)
FD_Curves_smooth.update(FD_Curves_smooth_part6)
FD_Curves_smooth.update(FD_Curves_smooth_part7)
FD_Curves_smooth.update(FD_Curves_smooth_part8)

FD_Curves_unsmooth.update(FD_Curves_unsmooth_part1)
FD_Curves_unsmooth.update(FD_Curves_unsmooth_part2)
FD_Curves_unsmooth.update(FD_Curves_unsmooth_part3)
FD_Curves_unsmooth.update(FD_Curves_unsmooth_part4)
FD_Curves_unsmooth.update(FD_Curves_unsmooth_part5)
FD_Curves_unsmooth.update(FD_Curves_unsmooth_part6)
FD_Curves_unsmooth.update(FD_Curves_unsmooth_part7)
FD_Curves_unsmooth.update(FD_Curves_unsmooth_part8)

flowCurves.update(flowCurves_part1)
flowCurves.update(flowCurves_part2)
flowCurves.update(flowCurves_part3)
flowCurves.update(flowCurves_part4)
flowCurves.update(flowCurves_part5)
flowCurves.update(flowCurves_part6)
flowCurves.update(flowCurves_part7)
flowCurves.update(flowCurves_part8)

np.save("MOO_results/DP1000_25C_SwiftVoce_curve1/SH/initial/common/FD_Curves_smooth.npy", FD_Curves_smooth)
np.save("MOO_results/DP1000_25C_SwiftVoce_curve1/SH/initial/common/FD_Curves_unsmooth.npy", FD_Curves_unsmooth)
np.save("MOO_results/DP1000_25C_SwiftVoce_curve1/SH/initial/common/flowCurves.npy", flowCurves)

# %%
# Copying all files from the initial folder to the common folder

path1 = "notebooks/SH/025/data"
path2 = "notebooks/SH/2550/data"
path3 = "notebooks/SH/5075/data"
path4 = "notebooks/SH/75100/data"
path5 = "notebooks/SH/100125/data"
path6 = "notebooks/SH/125150/data"
path7 = "notebooks/SH/150175/data"
path8 = "notebooks/SH/175200/data"

dest = "MOO_results/DP1000_25C_SwiftVoce_curve1/SH/initial/data"

copy_recursive(path2, dest)
# renaming all subfolders 1-25 as 26-50
for i in range(1,26):
    os.rename(os.path.join(dest, str(i)), os.path.join(dest, str(i+25)))

copy_recursive(path3, dest)
# renaming all subfolders 1-25 as 51-75
for i in range(1,26):
    os.rename(os.path.join(dest, str(i)), os.path.join(dest, str(i+50)))

copy_recursive(path4, dest)
# renaming all subfolders 1-25 as 76-100
for i in range(1,26):
    os.rename(os.path.join(dest, str(i)), os.path.join(dest, str(i+75)))

copy_recursive(path5, dest)
# renaming all subfolders 1-25 as 101-125
for i in range(1,26):
    os.rename(os.path.join(dest, str(i)), os.path.join(dest, str(i+100)))
copy_recursive(path6, dest)
# renaming all subfolders 1-25 as 126-150
for i in range(1,26):
    os.rename(os.path.join(dest, str(i)), os.path.join(dest, str(i+125)))

copy_recursive(path7, dest)
# renaming all subfolders 1-25 as 151-175
for i in range(1,26):
    os.rename(os.path.join(dest, str(i)), os.path.join(dest, str(i+150)))

copy_recursive(path8, dest)
# renaming all subfolders 1-25 as 176-200
for i in range(1,26):
    os.rename(os.path.join(dest, str(i)), os.path.join(dest, str(i+175)))

copy_recursive(path1, dest)
